# %% [markdown]
# # The impact of air pollution on the health sector with emphasis on respiratory diseases.

# %%
#Importing our Libraries
import pandas as pd 
import numpy as np

# %% [markdown]
# ## Functions to Loading the  datasets

# %%
#Function to load the datasets
def Data_frames(type,data):
    if type=='csv':
        My_data=pd.read_csv(data)
        return My_data
    else:
        My_data=pd.read_excel(data,header=1)
        return My_data

# %%
#The Mortality rate dataset
Data_frames('csv','Death due to respiratory conditions (new).csv')
# Out:
#      IndicatorCode                                          Indicator  \
# 0            AIR_5  Ambient air pollution attributable death rate ...
# 1            AIR_5  Ambient air pollution attributable death rate ...
# 2            AIR_5  Ambient air pollution attributable death rate ...
# 3            AIR_5  Ambient air pollution attributable death rate ...
# 4            AIR_5  Ambient air pollution attributable death rate ...
# ...            ...                                                ...
# 3289         AIR_5  Ambient air pollution attributable death rate ...
# 3290         AIR_5  Ambient air pollution attributable death rate ...
# 3291         AIR_5  Ambient air pollution attributable death rate ...
# 3292         AIR_5  Ambient air pollution attributable death rate ...
# 3293         AIR_5  Ambient air pollution attributable death rate ...
#
#      ValueType ParentLocationCode   ParentLocation Location type  \
# 0      numeric                AFR           Africa       Country
# 1      numeric                AFR           Africa       Country
# 2      numeric                AFR           Africa       Country
# 3      numeric                AFR           Africa       Country
# 4      numeric                AFR           Africa       Country
# ...        ...                ...              ...           ...
# 3289   numeric                EUR           Europe       Country
# 3290   numeric                EUR           Europe       Country
# 3291   numeric                EUR           Europe       Country
# 3292   numeric                EUR           Europe       Country
# 3293   numeric               SEAR  South-East Asia       Country
#
#      SpatialDimValueCode                               Location Period type  \
# 0                    MWI                                 Malawi        Year
# 1                    NER                                  Niger        Year
# 2                    TZA            United Republic of Tanzania        Year
# 3                    TZA            United Republic of Tanzania        Year
# 4                    MWI                                 Malawi        Year
# ...                  ...                                    ...         ...
# 3289                 UKR                                Ukraine        Year
# 3290                 UKR                                Ukraine        Year
# 3291                 UKR                                Ukraine        Year
# 3292                 BLR                                Belarus        Year
# 3293                 PRK  Democratic People's Republic of Korea        Year
#
#       Period  ...  FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 0       2016  ...           NaN                       NaN               0.022
# 1       2016  ...           NaN                       NaN               0.032
# 2       2016  ...           NaN                       NaN               0.029
# 3       2016  ...           NaN                       NaN               0.031
# 4       2016  ...           NaN                       NaN               0.030
# ...      ...  ...           ...                       ...                 ...
# 3289    2016  ...           NaN                       NaN              72.370
# 3290    2016  ...           NaN                       NaN              69.010
# 3291    2016  ...           NaN                       NaN              64.720
# 3292    2016  ...           NaN                       NaN              69.350
# 3293    2016  ...           NaN                       NaN              81.170
#
#      FactValueNumericHighPrefix FactValueNumericHigh                  Value  \
# 0                           NaN                0.061   0.04 [0.022 – 0.061]
# 1                           NaN                0.062  0.047 [0.032 – 0.062]
# 2                           NaN                0.076  0.051 [0.029 – 0.076]
# 3                           NaN                0.083  0.055 [0.031 – 0.083]
# 4                           NaN                0.086   0.056 [0.03 – 0.086]
# ...                         ...                  ...                    ...
# 3289                        NaN              113.300  92.97 [72.37 – 113.3]
# 3290                        NaN              117.400  93.01 [69.01 – 117.4]
# 3291                        NaN              122.900  93.05 [64.72 – 122.9]
# 3292                        NaN              122.800  95.15 [69.35 – 122.8]
# 3293                        NaN              112.900  96.42 [81.17 – 112.9]
#
#      FactValueTranslationID  FactComments  Language              DateModified
# 0                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 1                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 2                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 4                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# ...                     ...           ...       ...                       ...
# 3289                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3290                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3291                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3292                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3293                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
#
# [3294 rows x 34 columns]

# %%
#Loading the PM concentration dataset
Data_frames('csv','Particulate Matter Concentration world wide...csv')

# %%
#Loading the WHO Air Quality database
Data_frames('csv','WHO_AirQuality_Database_2016_Africa.csv')

# %%
# CO2 emission dataset
Data_frames('csv',"CO2 Emission in KT. in excel.csv")

# %%
# NO emission dataset
Data_frames('xlsx','Nitogen Oxide Emissions edited.xlsx')

# %% [markdown]
# ## Function to check the attributes of our datasets.

# %%
# This function  checks the nesessary attributes of the dataset
def attributes(type,data):
    if type=='csv':
        My_df=pd.read_csv(data)
        print(My_df.shape)
        print('\n')
        print(My_df.isnull().sum())
        print('\n')
        print(My_df.duplicated().any())
        print('\n')
        print(My_df.info)
    else:
        My_df=pd.read_excel(data,header=1)
        print(My_df.shape)
        print('\n')
        print(My_df.isnull().sum())
        print('\n')
        print(My_df.duplicated().any())
        print('\n')
        print(My_df.info)

# %%
#Mortality rate attributes
attributes('csv','Death due to respiratory conditions (new).csv')
# Out:
# (3294, 34)
#
#
# IndicatorCode                    0
# Indicator                        0
# ValueType                        0
# ParentLocationCode               0
# ParentLocation                   0
# Location type                    0
# SpatialDimValueCode              0
# Location                         0
# Period type                      0
# Period                           0
# IsLatestYear                     0
# Dim1 type                        0
# Dim1                             0
# Dim1ValueCode                    0
# Dim2 type                        0
# Dim2                             0
# Dim2ValueCode                    0
# Dim3 type                     3294
# Dim3                          3294
# Dim3ValueCode                 3294
# DataSourceDimValueCode        3294
# DataSource                    3294
# FactValueNumericPrefix        3294
# FactValueNumeric                 0
# FactValueUoM                  3294
# FactValueNumericLowPrefix     3294
# FactValueNumericLow              0
# FactValueNumericHighPrefix    3294
# FactValueNumericHigh             0
# Value                            0
# FactValueTranslationID        3294
# FactComments                  3294
# Language                         0
# DateModified                     0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of      IndicatorCode                                          Indicator  \
# 0            AIR_5  Ambient air pollution attributable death rate ...
# 1            AIR_5  Ambient air pollution attributable death rate ...
# 2            AIR_5  Ambient air pollution attributable death rate ...
# 3            AIR_5  Ambient air pollution attributable death rate ...
# 4            AIR_5  Ambient air pollution attributable death rate ...
# ...            ...                                                ...
# 3289         AIR_5  Ambient air pollution attributable death rate ...
# 3290         AIR_5  Ambient air pollution attributable death rate ...
# 3291         AIR_5  Ambient air pollution attributable death rate ...
# 3292         AIR_5  Ambient air pollution attributable death rate ...
# 3293         AIR_5  Ambient air pollution attributable death rate ...
#
#      ValueType ParentLocationCode   ParentLocation Location type  \
# 0      numeric                AFR           Africa       Country
# 1      numeric                AFR           Africa       Country
# 2      numeric                AFR           Africa       Country
# 3      numeric                AFR           Africa       Country
# 4      numeric                AFR           Africa       Country
# ...        ...                ...              ...           ...
# 3289   numeric                EUR           Europe       Country
# 3290   numeric                EUR           Europe       Country
# 3291   numeric                EUR           Europe       Country
# 3292   numeric                EUR           Europe       Country
# 3293   numeric               SEAR  South-East Asia       Country
#
#      SpatialDimValueCode                               Location Period type  \
# 0                    MWI                                 Malawi        Year
# 1                    NER                                  Niger        Year
# 2                    TZA            United Republic of Tanzania        Year
# 3                    TZA            United Republic of Tanzania        Year
# 4                    MWI                                 Malawi        Year
# ...                  ...                                    ...         ...
# 3289                 UKR                                Ukraine        Year
# 3290                 UKR                                Ukraine        Year
# 3291                 UKR                                Ukraine        Year
# 3292                 BLR                                Belarus        Year
# 3293                 PRK  Democratic People's Republic of Korea        Year
#
#       Period  ...  FactValueUoM FactValueNumericLowPrefix FactValueNumericLow  \
# 0       2016  ...           NaN                       NaN               0.022
# 1       2016  ...           NaN                       NaN               0.032
# 2       2016  ...           NaN                       NaN               0.029
# 3       2016  ...           NaN                       NaN               0.031
# 4       2016  ...           NaN                       NaN               0.030
# ...      ...  ...           ...                       ...                 ...
# 3289    2016  ...           NaN                       NaN              72.370
# 3290    2016  ...           NaN                       NaN              69.010
# 3291    2016  ...           NaN                       NaN              64.720
# 3292    2016  ...           NaN                       NaN              69.350
# 3293    2016  ...           NaN                       NaN              81.170
#
#      FactValueNumericHighPrefix FactValueNumericHigh                  Value  \
# 0                           NaN                0.061   0.04 [0.022 – 0.061]
# 1                           NaN                0.062  0.047 [0.032 – 0.062]
# 2                           NaN                0.076  0.051 [0.029 – 0.076]
# 3                           NaN                0.083  0.055 [0.031 – 0.083]
# 4                           NaN                0.086   0.056 [0.03 – 0.086]
# ...                         ...                  ...                    ...
# 3289                        NaN              113.300  92.97 [72.37 – 113.3]
# 3290                        NaN              117.400  93.01 [69.01 – 117.4]
# 3291                        NaN              122.900  93.05 [64.72 – 122.9]
# 3292                        NaN              122.800  95.15 [69.35 – 122.8]
# 3293                        NaN              112.900  96.42 [81.17 – 112.9]
#
#      FactValueTranslationID  FactComments  Language              DateModified
# 0                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 1                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 2                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 4                       NaN           NaN        EN  2018-07-05T21:00:00.000Z
# ...                     ...           ...       ...                       ...
# 3289                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3290                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3291                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3292                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
# 3293                    NaN           NaN        EN  2018-07-05T21:00:00.000Z
#
# [3294 rows x 34 columns]>

# %%
#Particulate Matter concentration attributes
attributes('csv','Particulate Matter Concentration world wide...csv')
# Out:
# (4032, 34)
#
#
# IndicatorCode                    0
# Indicator                        0
# ValueType                        0
# ParentLocationCode               0
# ParentLocation                   0
# Location type                    0
# SpatialDimValueCode              0
# Location                         0
# Period type                      0
# Period                           0
# IsLatestYear                     0
# Dim1 type                        0
# Dim1                             0
# Dim1ValueCode                    0
# Dim2 type                     4032
# Dim2                          4032
# Dim2ValueCode                 4032
# Dim3 type                     4032
# Dim3                          4032
# Dim3ValueCode                 4032
# DataSourceDimValueCode        4032
# DataSource                    4032
# FactValueNumericPrefix        4032
# FactValueNumeric                 0
# FactValueUoM                  4032
# FactValueNumericLowPrefix     4032
# FactValueNumericLow              0
# FactValueNumericHighPrefix    4032
# FactValueNumericHigh             0
# Value                            0
# FactValueTranslationID        4032
# FactComments                  4032
# Language                         0
# DateModified                     0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of      IndicatorCode                                          Indicator  \
# 0          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 1          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 2          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 3          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4          SDGPM25  Concentrations of fine particulate matter (PM2.5)
# ...            ...                                                ...
# 4027       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4028       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4029       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4030       SDGPM25  Concentrations of fine particulate matter (PM2.5)
# 4031       SDGPM25  Concentrations of fine particulate matter (PM2.5)
#
#      ValueType ParentLocationCode   ParentLocation Location type  \
# 0         text                EUR           Europe       Country
# 1         text                EUR           Europe       Country
# 2         text                EUR           Europe       Country
# 3         text                EUR           Europe       Country
# 4         text                EUR           Europe       Country
# ...        ...                ...              ...           ...
# 4027      text                AMR         Americas       Country
# 4028      text                EUR           Europe       Country
# 4029      text                EUR           Europe       Country
# 4030      text                WPR  Western Pacific       Country
# 4031      text                EUR           Europe       Country
#
#      SpatialDimValueCode                                           Location  \
# 0                    LVA                                             Latvia
# 1                    LUX                                         Luxembourg
# 2                    SMR                                         San Marino
# 3                    SMR                                         San Marino
# 4                    DNK                                            Denmark
# ...                  ...                                                ...
# 4027                 USA                           United States of America
# 4028                 PRT                                           Portugal
# 4029                 NOR                                             Norway
# 4030                 JPN                                              Japan
# 4031                 GBR  United Kingdom of Great Britain and Northern I...
#
#      Period type  Period  ...  FactValueUoM FactValueNumericLowPrefix  \
# 0           Year    2016  ...           NaN                       NaN
# 1           Year    2016  ...           NaN                       NaN
# 2           Year    2016  ...           NaN                       NaN
# 3           Year    2016  ...           NaN                       NaN
# 4           Year    2016  ...           NaN                       NaN
# ...          ...     ...  ...           ...                       ...
# 4027        Year    2010  ...           NaN                       NaN
# 4028        Year    2010  ...           NaN                       NaN
# 4029        Year    2010  ...           NaN                       NaN
# 4030        Year    2010  ...           NaN                       NaN
# 4031        Year    2010  ...           NaN                       NaN
#
#      FactValueNumericLow FactValueNumericHighPrefix  FactValueNumericHigh  \
# 0                   8.33                        NaN                 12.10
# 1                   9.25                        NaN                 10.72
# 2                   7.63                        NaN                 13.76
# 3                   7.63                        NaN                 13.76
# 4                   9.36                        NaN                 11.31
# ...                  ...                        ...                   ...
# 4027                9.24                        NaN                  9.52
# 4028                8.92                        NaN                  9.98
# 4029                8.84                        NaN                 10.03
# 4030                8.86                        NaN                 11.51
# 4031                9.28                        NaN                 10.56
#
#                      Value  FactValueTranslationID  FactComments  Language  \
# 0         10 [8.33 – 12.1]                     NaN           NaN        EN
# 1     10.02 [9.25 – 10.72]                     NaN           NaN        EN
# 2     10.06 [7.63 – 13.76]                     NaN           NaN        EN
# 3     10.06 [7.63 – 13.76]                     NaN           NaN        EN
# 4     10.11 [9.36 – 11.31]                     NaN           NaN        EN
# ...                    ...                     ...           ...       ...
# 4027    9.44 [9.24 – 9.52]                     NaN           NaN        EN
# 4028    9.48 [8.92 – 9.98]                     NaN           NaN        EN
# 4029    9.5 [8.84 – 10.03]                     NaN           NaN        EN
# 4030    9.9 [8.86 – 11.51]                     NaN           NaN        EN
# 4031   9.97 [9.28 – 10.56]                     NaN           NaN        EN
#
#                   DateModified
# 0     2021-05-06T21:00:00.000Z
# 1     2021-05-06T21:00:00.000Z
# 2     2021-05-06T21:00:00.000Z
# 3     2021-05-06T21:00:00.000Z
# 4     2021-05-06T21:00:00.000Z
# ...                        ...
# 4027  2021-05-06T21:00:00.000Z
# 4028  2021-05-06T21:00:00.000Z
# 4029  2021-05-06T21:00:00.000Z
# 4030  2021-05-06T21:00:00.000Z
# 4031  2021-05-06T21:00:00.000Z
#
# [4032 rows x 34 columns]>

# %%
#WHO Air Quality database attributes
attributes('csv','WHO_AirQuality_Database_2016_Africa.csv')
# Out:
# (2965, 30)
#
#
# ID WHO city          2965
# iso3                    0
# country                 0
# city                    0
# pm10                    0
# Year                    0
# type_of_stations       55
# pm10_type               0
# pm25                    0
# pm25_type               0
# reference               1
# latitude                0
# longitude               0
# population              0
# wbinc16_text            0
# region                  0
# date_compiled           0
# population_source       8
# tempcov_PM10          885
# tempcov_PM25         1672
# latitude_pop         2962
# longitude_pop        2962
# Region                  0
# region_abbr             0
# tempcov_PM10_grad     885
# tempcov_PM25_grad    1672
# conc_pm25               0
# color_pm25              0
# conc_pm10               0
# color_pm10              0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of       ID WHO city iso3       country                city        pm10  Year  \
# 0             NaN  ALB       Albania              Durres   24.531701  2016
# 1             NaN  ALB       Albania               Korce   40.184920  2016
# 2             NaN  ALB       Albania               Vlore   22.699357  2016
# 3             NaN  AND       Andorra  Escaldes-Engordany   22.829476  2016
# 4             NaN  ARG     Argentina        Buenos Aires   26.878788  2016
# ...           ...  ...           ...                 ...         ...   ...
# 2960          NaN  GHA         Ghana               Accra  112.200000  2016
# 2961          NaN  ECU       Ecuador              Cuenca   43.590000  2016
# 2962          NaN  SAU  Saudi Arabia              Jubail  129.068884  2016
# 2963          NaN  SAU  Saudi Arabia              Riyadh  251.000000  2016
# 2964          NaN  SAU  Saudi Arabia              Dammam  161.000000  2016
#
#            type_of_stations  pm10_type       pm25  pm25_type  ...  \
# 0           1 Urban-Traffic   Measured  14.298273   Measured  ...
# 1     1 Suburban-Background   Measured  28.615831   Measured  ...
# 2        1 Urban-Background   Measured  15.297521  Converted  ...
# 3        1 Urban-Background   Measured  11.500000   Measured  ...
# 4                    3 N.A.   Measured  12.449308  Converted  ...
# ...                     ...        ...        ...        ...  ...
# 2960                  Urban  Converted  55.000000   Measured  ...
# 2961                 3 N.A.   Measured  10.280000   Measured  ...
# 2962  5 Industrial, 3 Urban   Measured  58.000000   Measured  ...
# 2963                 1 N.A.   Measured  73.000000   Measured  ...
# 2964                 1 N.A.   Measured  56.000000   Measured  ...
#
#      latitude_pop  longitude_pop                       Region  region_abbr  \
# 0             NaN            NaN                Europe (LMIC)   Eur (LMIC)
# 1             NaN            NaN                Europe (LMIC)   Eur (LMIC)
# 2             NaN            NaN                Europe (LMIC)   Eur (LMIC)
# 3             NaN            NaN                 Europe (HIC)    Eur (HIC)
# 4             NaN            NaN              Americas (LMIC)   Amr (LMIC)
# ...           ...            ...                          ...          ...
# 2960          NaN            NaN  Africa (Sub-Saharan) (LMIC)          Afr
# 2961          NaN            NaN              Americas (LMIC)   Amr (LMIC)
# 2962          NaN            NaN  Eastern Mediterranean (HIC)    Emr (HIC)
# 2963    24.690466      46.709566  Eastern Mediterranean (HIC)    Emr (HIC)
# 2964    26.392666      49.977715  Eastern Mediterranean (HIC)    Emr (HIC)
#
#      tempcov_PM10_grad tempcov_PM25_grad  conc_pm25  color_pm25  conc_pm10  \
# 0                 >75%              >75%     10-<15      yellow     20-<30
# 1                 >75%              >75%     25-<35  darkorange     30-<50
# 2                 >75%               NaN     15-<25      orange     20-<30
# 3                 >75%               NaN     10-<15      yellow     20-<30
# 4                 >75%               NaN     10-<15      yellow     20-<30
# ...                ...               ...        ...         ...        ...
# 2960               NaN               NaN        >50     darkred       >100
# 2961               NaN               NaN     10-<15      yellow     30-<50
# 2962              >75%              >75%        >50     darkred       >100
# 2963               NaN               NaN        >50     darkred       >100
# 2964               NaN               NaN        >50     darkred       >100
#
#       color_pm10
# 0         yellow
# 1        darkred
# 2         yellow
# 3         yellow
# 4         yellow
# ...          ...
# 2960     darkred
# 2961     darkred
# 2962     darkred
# 2963     darkred
# 2964     darkred
#
# [2965 rows x 30 columns]>

# %%
#CO2 Concentration attributes
attributes('csv',"CO2 Emission in KT. in excel.csv")
# Out:
# (61, 65)
#
#
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1960              10
#                   ..
# 2016               0
# 2017               0
# 2018               0
# 2019              61
# 2020              61
# Length: 65, dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of                    Country Name Country Code      Indicator Name  \
# 0   Africa Eastern and Southern          AFE  CO2 emissions (kt)
# 1    Africa Western and Central          AFW  CO2 emissions (kt)
# 2                        Angola          AGO  CO2 emissions (kt)
# 3                       Burundi          BDI  CO2 emissions (kt)
# 4                         Benin          BEN  CO2 emissions (kt)
# ..                          ...          ...                 ...
# 56                     Tanzania          TZA  CO2 emissions (kt)
# 57                       Uganda          UGA  CO2 emissions (kt)
# 58                 South Africa          ZAF  CO2 emissions (kt)
# 59                       Zambia          ZMB  CO2 emissions (kt)
# 60                     Zimbabwe          ZWE  CO2 emissions (kt)
#
#     Indicator Code         1960         1961         1962         1963  \
# 0   EN.ATM.CO2E.KT  118545.9013  123758.9033  128093.8978  132810.3325
# 1   EN.ATM.CO2E.KT    8760.4630    9376.5190    9710.2160   11540.0490
# 2   EN.ATM.CO2E.KT     550.0500     454.7080    1180.7740    1151.4380
# 3   EN.ATM.CO2E.KT          NaN          NaN      44.0040      47.6710
# 4   EN.ATM.CO2E.KT     161.3480     128.3450     135.6790     121.0110
# ..             ...          ...          ...          ...          ...
# 56  EN.ATM.CO2E.KT     828.7420     704.0640     766.4030     803.0730
# 57  EN.ATM.CO2E.KT     421.7050     407.0370     429.0390     432.7060
# 58  EN.ATM.CO2E.KT   97934.5690  102213.9580  105767.2810  109826.6500
# 59  EN.ATM.CO2E.KT          NaN          NaN          NaN          NaN
# 60  EN.ATM.CO2E.KT          NaN          NaN          NaN          NaN
#
#            1964         1965  ...         2011         2012        2013  \
# 0   144345.3524  155803.7801  ...  535604.3575  559333.8573  580510.925
# 1    13985.9380   19827.4690  ...  179070.0000  181740.0000  191990.000
# 2     1224.7780    1188.1080  ...   29460.0000   30250.0000   32820.000
# 3       47.6710      36.6700  ...     370.0000     390.0000     410.000
# 4      143.0130     150.3470  ...    4980.0000    4740.0000    5020.000
# ..          ...          ...  ...          ...          ...         ...
# 56    1034.0940    1162.4390  ...    8160.0000    9870.0000   10810.000
# 57     491.3780     627.0570  ...    4160.0000    3910.0000    4270.000
# 58  119657.8770  128260.6590  ...  409120.0000  426710.0000  436870.000
# 59    3278.2980    3916.3560  ...    3060.0000    4020.0000    4240.000
# 60    4473.7400    5214.4740  ...   11490.0000   12110.0000   12360.000
#
#           2014        2015        2016         2017         2018  2019  2020
# 0   601860.164  586385.004  592299.594  601323.3947  600351.1333   NaN   NaN
# 1   198440.000  193060.000  195120.000  201900.0000  224380.0000   NaN   NaN
# 2    34630.000   35160.000   35410.000   30840.0000   27340.0000   NaN   NaN
# 3      390.000     410.000     460.000     570.0000     590.0000   NaN   NaN
# 4     5510.000    5990.000    7230.000    7360.0000    7910.0000   NaN   NaN
# ..         ...         ...         ...          ...          ...   ...   ...
# 56   10720.000   11690.000   10920.000   11360.0000   11580.0000   NaN   NaN
# 57    4740.000    4860.000    5670.000    5840.0000    6130.0000   NaN   NaN
# 58  447980.000  424880.000  425180.000  435140.0000  433250.0000   NaN   NaN
# 59    4800.000    5070.000    5590.000    6990.0000    7740.0000   NaN   NaN
# 60   12150.000   12400.000   10990.000   10230.0000   12270.0000   NaN   NaN
#
# [61 rows x 65 columns]>

# %%
# NO concentration attributes
attributes('xlsx','Nitogen Oxide Emissions edited.xlsx')
# Out:
# (59, 65)
#
#
# Country Name       0
# Country Code       0
# Indicator Name     0
# Indicator Code     0
# 1960              59
#                   ..
# 2016               0
# 2017               0
# 2018               0
# 2019              59
# 2020              59
# Length: 65, dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of                                          Country Name Country Code  \
# 0                         Africa Eastern and Southern          AFE
# 1                          Africa Western and Central          AFW
# 2                                              Angola          AGO
# 3                                             Burundi          BDI
# 4                                               Benin          BEN
# 5                                        Burkina Faso          BFA
# 6                                            Botswana          BWA
# 7                            Central African Republic          CAF
# 8                                       Cote d'Ivoire          CIV
# 9                                            Cameroon          CMR
# 10                                   Congo, Dem. Rep.          COD
# 11                                        Congo, Rep.          COG
# 12                                            Comoros          COM
# 13                                         Cabo Verde          CPV
# 14                                           Djibouti          DJI
# 15                                            Algeria          DZA
# 16                                   Egypt, Arab Rep.          EGY
# 17                                            Eritrea          ERI
# 18                                           Ethiopia          ETH
# 19                                              Gabon          GAB
# 20                                              Ghana          GHA
# 21                                             Guinea          GIN
# 22                                        Gambia, The          GMB
# 23                                      Guinea-Bissau          GNB
# 24                                              Kenya          KEN
# 25                                            Liberia          LBR
# 26                                              Libya          LBY
# 27                                            Lesotho          LSO
# 28                                            Morocco          MAR
# 29                                         Madagascar          MDG
# 30                         Middle East & North Africa          MEA
# 31                                               Mali          MLI
# 32  Middle East & North Africa (excluding high inc...          MNA
# 33                                         Mozambique          MOZ
# 34                                         Mauritania          MRT
# 35                                          Mauritius          MUS
# 36                                             Malawi          MWI
# 37                                            Namibia          NAM
# 38                                              Niger          NER
# 39                                            Nigeria          NGA
# 40                                             Rwanda          RWA
# 41                                              Sudan          SDN
# 42                                            Senegal          SEN
# 43                                       Sierra Leone          SLE
# 44                                            Somalia          SOM
# 45                                        South Sudan          SSD
# 46                                 Sub-Saharan Africa          SSF
# 47                                           Eswatini          SWZ
# 48                                         Seychelles          SYC
# 49                                               Chad          TCD
# 50                                               Togo          TGO
# 51  Middle East & North Africa (IDA & IBRD countries)          TMN
# 52          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 53                                            Tunisia          TUN
# 54                                           Tanzania          TZA
# 55                                             Uganda          UGA
# 56                                       South Africa          ZAF
# 57                                             Zambia          ZMB
# 58                                           Zimbabwe          ZWE
#
#                                        Indicator Name     Indicator Code  \
# 0   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 1   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 2   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 3   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 4   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 5   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 6   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 7   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 8   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 9   Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 10  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 11  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 12  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 13  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 14  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 15  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 16  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 17  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 18  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 19  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 20  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 21  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 22  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 23  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 24  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 25  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 26  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 27  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 28  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 29  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 30  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 31  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 32  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 33  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 34  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 35  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 36  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 37  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 38  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 39  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 40  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 41  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 42  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 43  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 44  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 45  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 46  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 47  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 48  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 49  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 50  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 51  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 52  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 53  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 54  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 55  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 56  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 57  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
# 58  Nitrous oxide emissions (thousand metric tons ...  EN.ATM.NOXE.KT.CE
#
#     1960  1961  1962  1963  1964  1965  ...    2011    2012    2013    2014  \
# 0    NaN   NaN   NaN   NaN   NaN   NaN  ...  272840  275740  274830  276360
# 1    NaN   NaN   NaN   NaN   NaN   NaN  ...  201630  204520  210520  212830
# 2    NaN   NaN   NaN   NaN   NaN   NaN  ...   18270   17330   17900   17350
# 3    NaN   NaN   NaN   NaN   NaN   NaN  ...    1780    1810    1960    1970
# 4    NaN   NaN   NaN   NaN   NaN   NaN  ...    2340    2400    2510    2510
# 5    NaN   NaN   NaN   NaN   NaN   NaN  ...    8790    8850    9140    9220
# 6    NaN   NaN   NaN   NaN   NaN   NaN  ...   11210    4940    4440    3080
# 7    NaN   NaN   NaN   NaN   NaN   NaN  ...   27170   26840   28660   29590
# 8    NaN   NaN   NaN   NaN   NaN   NaN  ...    3160    3190    3420    3010
# 9    NaN   NaN   NaN   NaN   NaN   NaN  ...   62430   62370   62570   62490
# 10   NaN   NaN   NaN   NaN   NaN   NaN  ...   14940   14920   15730   15500
# 11   NaN   NaN   NaN   NaN   NaN   NaN  ...    1950    1890    1970    1760
# 12   NaN   NaN   NaN   NaN   NaN   NaN  ...      50      50      50      50
# 13   NaN   NaN   NaN   NaN   NaN   NaN  ...      70      80      80      80
# 14   NaN   NaN   NaN   NaN   NaN   NaN  ...     260     260     260     270
# 15   NaN   NaN   NaN   NaN   NaN   NaN  ...    9110   10030   10580   11310
# 16   NaN   NaN   NaN   NaN   NaN   NaN  ...   23650   22630   22110   21640
# 17   NaN   NaN   NaN   NaN   NaN   NaN  ...    3500    3320    3150    2970
# 18   NaN   NaN   NaN   NaN   NaN   NaN  ...   42140   44600   45710   47710
# 19   NaN   NaN   NaN   NaN   NaN   NaN  ...     430     430     450     400
# 20   NaN   NaN   NaN   NaN   NaN   NaN  ...    5310    5220    5630    5560
# 21   NaN   NaN   NaN   NaN   NaN   NaN  ...    5320    5890    5920    6000
# 22   NaN   NaN   NaN   NaN   NaN   NaN  ...     390     350     370     380
# 23   NaN   NaN   NaN   NaN   NaN   NaN  ...     730     790     740     770
# 24   NaN   NaN   NaN   NaN   NaN   NaN  ...   17260   17130   17090   18080
# 25   NaN   NaN   NaN   NaN   NaN   NaN  ...     870     980    1090    1220
# 26   NaN   NaN   NaN   NaN   NaN   NaN  ...    2000    2010    2010    1910
# 27   NaN   NaN   NaN   NaN   NaN   NaN  ...     790     800     780     790
# 28   NaN   NaN   NaN   NaN   NaN   NaN  ...    8570    8140    8930    8830
# 29   NaN   NaN   NaN   NaN   NaN   NaN  ...    8610    8820    8610    8600
# 30   NaN   NaN   NaN   NaN   NaN   NaN  ...  112470  113450  114770  114010
# 31   NaN   NaN   NaN   NaN   NaN   NaN  ...   10950   11120   11650   11810
# 32   NaN   NaN   NaN   NaN   NaN   NaN  ...   97670   98230   98560   97590
# 33   NaN   NaN   NaN   NaN   NaN   NaN  ...   10080   10430   10680   10980
# 34   NaN   NaN   NaN   NaN   NaN   NaN  ...    2850    2940    3010    2980
# 35   NaN   NaN   NaN   NaN   NaN   NaN  ...     250     260     230     250
# 36   NaN   NaN   NaN   NaN   NaN   NaN  ...    3230    3280    3420    3860
# 37   NaN   NaN   NaN   NaN   NaN   NaN  ...    6630    7230    3600    3040
# 38   NaN   NaN   NaN   NaN   NaN   NaN  ...    8740    9310    9710   10240
# 39   NaN   NaN   NaN   NaN   NaN   NaN  ...   32040   32890   33660   34080
# 40   NaN   NaN   NaN   NaN   NaN   NaN  ...    1700    1770    1810    1790
# 41   NaN   NaN   NaN   NaN   NaN   NaN  ...   26290   27690   28150   28130
# 42   NaN   NaN   NaN   NaN   NaN   NaN  ...    7260    7050    7420    7420
# 43   NaN   NaN   NaN   NaN   NaN   NaN  ...    1270    1660    1550    1660
# 44   NaN   NaN   NaN   NaN   NaN   NaN  ...    6640    6720    6750    6760
# 45   NaN   NaN   NaN   NaN   NaN   NaN  ...   20510   22220   21650   21960
# 46   NaN   NaN   NaN   NaN   NaN   NaN  ...  474470  480260  485350  489190
# 47   NaN   NaN   NaN   NaN   NaN   NaN  ...     450     450     450     450
# 48   NaN   NaN   NaN   NaN   NaN   NaN  ...       0       0       0       0
# 49   NaN   NaN   NaN   NaN   NaN   NaN  ...   17670   18610   19180   19970
# 50   NaN   NaN   NaN   NaN   NaN   NaN  ...    1850    1620    1750    1640
# 51   NaN   NaN   NaN   NaN   NaN   NaN  ...   97670   98230   98560   97590
# 52   NaN   NaN   NaN   NaN   NaN   NaN  ...  474470  480260  485350  489190
# 53   NaN   NaN   NaN   NaN   NaN   NaN  ...    3410    3430    3160    3260
# 54   NaN   NaN   NaN   NaN   NaN   NaN  ...   25510   27170   28390   29030
# 55   NaN   NaN   NaN   NaN   NaN   NaN  ...   12890   13670   13670   13890
# 56   NaN   NaN   NaN   NaN   NaN   NaN  ...   19420   19720   19090   19330
# 57   NaN   NaN   NaN   NaN   NaN   NaN  ...   13810   14880   15190   14930
# 58   NaN   NaN   NaN   NaN   NaN   NaN  ...    6860    6510    6310    5840
#
#       2015    2016    2017    2018  2019  2020
# 0   279960  284380  286140  286710   NaN   NaN
# 1   218280  228580  229100  230890   NaN   NaN
# 2    17950   18070   18490   16440   NaN   NaN
# 3     1940    2090    2300    2360   NaN   NaN
# 4     2470    2670    2570    2930   NaN   NaN
# 5     9310    9830    9860    9850   NaN   NaN
# 6     2790    2430    4140    3160   NaN   NaN
# 7    30910   32140   31620   32110   NaN   NaN
# 8     3090    3680    3080    3030   NaN   NaN
# 9    62610   62700   62680   62710   NaN   NaN
# 10   16170   16060   16630   15790   NaN   NaN
# 11    1950    1980    1960    2010   NaN   NaN
# 12      50      50      50      50   NaN   NaN
# 13      80      80      70      70   NaN   NaN
# 14     270     270     270     270   NaN   NaN
# 15   11870   11890   11920   12110   NaN   NaN
# 16   21630   22130   22050   22320   NaN   NaN
# 17    2800    2840    2860    2900   NaN   NaN
# 18   49190   50870   51880   52160   NaN   NaN
# 19     430     440     490     430   NaN   NaN
# 20    5850    5900    6150    5790   NaN   NaN
# 21    5970    7210    6950    6590   NaN   NaN
# 22     390     390     390     400   NaN   NaN
# 23     800     770     800     830   NaN   NaN
# 24   17620   18760   17530   18330   NaN   NaN
# 25    1390    1360    1360    1370   NaN   NaN
# 26    1890    1940    1950    1970   NaN   NaN
# 27     800     790     850     820   NaN   NaN
# 28    9240    7940    9300    9430   NaN   NaN
# 29    8680    9170    8720    8770   NaN   NaN
# 30  114750  115790  117460  118840   NaN   NaN
# 31   12260   13730   13640   13820   NaN   NaN
# 32   97590   98310   99880  101050   NaN   NaN
# 33   10470    9780    9760   10700   NaN   NaN
# 34    3160    3370    3230    3220   NaN   NaN
# 35     220     240     230     230   NaN   NaN
# 36    4000    3870    4220    4970   NaN   NaN
# 37    3000    3260    3320    2870   NaN   NaN
# 38   10620   11190   11690   12250   NaN   NaN
# 39   34200   36210   37290   37420   NaN   NaN
# 40    2050    1980    2000    1960   NaN   NaN
# 41   28320   29670   29270   29610   NaN   NaN
# 42    7400    7920    7970    7820   NaN   NaN
# 43    1820    1750    1620    1410   NaN   NaN
# 44    6740    6680    6600    6570   NaN   NaN
# 45   22160   22800   21630   23010   NaN   NaN
# 46  498240  512960  515240  517600   NaN   NaN
# 47     430     430     440     440   NaN   NaN
# 48       0       0       0       0   NaN   NaN
# 49   21660   23360   23880   24920   NaN   NaN
# 50    1870    1860    1760    1870   NaN   NaN
# 51   97590   98310   99880  101050   NaN   NaN
# 52  498240  512960  515240  517600   NaN   NaN
# 53    3210    3340    3240    3320   NaN   NaN
# 54   30260   30680   29760   30340   NaN   NaN
# 55   14320   15070   15330   15460   NaN   NaN
# 56   18180   17510   19150   18820   NaN   NaN
# 57   15310   15170   14680   14460   NaN   NaN
# 58    6490    6090    6280    6470   NaN   NaN
#
# [59 rows x 65 columns]>

# %% [markdown]
# ## Cleaning the mortality rate dataset

# %%
M_data=Data_frames('csv','Death due to respiratory conditions (new).csv')
# Getting rid of columns with null values
M_data.dropna(axis=1,how='all',inplace=True)
M_data
# Dropping unnessesary columns
D_Mortality_data= M_data.drop(M_data.columns[[0,2,3,5,6,8,10,11,13,14,16,20,21,22]], axis = 1)
D_Mortality_data
# Renaming columns 
Africa_df=D_Mortality_data.rename(columns={'ParentLocation':'Continent','Location':'Country','Period':'Year','Dim1':'Gender','Dim2':'Cause'})
Africa_df
# Filtering out the African countries.
New_df=Africa_df[Africa_df['Continent']=='Africa']
New_df
# Constructing a new column with average
New_df['Average_death_Value']=New_df[['FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']].mean(axis=1)
#Dropping the Fact value Numeric columns
D_New_df=New_df.drop(New_df.columns[[6,7,8]],axis=1)
D_New_df
# Dropping duplicates
D_New_df.drop_duplicates
D_New_df.head()
# Out:
# <ipython-input-14-5eab3809d757>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   New_df['Average_death_Value']=New_df[['FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']].mean(axis=1)
#                                            Indicator Continent  \
# 0  Ambient air pollution attributable death rate ...    Africa
# 1  Ambient air pollution attributable death rate ...    Africa
# 2  Ambient air pollution attributable death rate ...    Africa
# 3  Ambient air pollution attributable death rate ...    Africa
# 4  Ambient air pollution attributable death rate ...    Africa
#
#                        Country  Year      Gender  \
# 0                       Malawi  2016      Female
# 1                        Niger  2016      Female
# 2  United Republic of Tanzania  2016      Female
# 3  United Republic of Tanzania  2016  Both sexes
# 4                       Malawi  2016  Both sexes
#
#                              Cause  Average_death_Value
# 0  Trachea, bronchus, lung cancers             0.041000
# 1  Trachea, bronchus, lung cancers             0.047000
# 2  Trachea, bronchus, lung cancers             0.052000
# 3  Trachea, bronchus, lung cancers             0.056333
# 4  Trachea, bronchus, lung cancers             0.057333

# %%
#Creating a function to confirming the cleaning operation
def new_attributes(data):
    print(data.shape)
    print('\n')
    print(data.isnull().sum())
    print('\n')
    print(data.duplicated().any())
    print('\n')
    print(data.info)

# %%
#Calling the function on Mortality dataset
new_attributes(D_New_df)
# Out:
# (954, 7)
#
#
# Indicator              0
# Continent              0
# Country                0
# Year                   0
# Gender                 0
# Cause                  0
# Average_death_Value    0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of                                               Indicator Continent  \
# 0     Ambient air pollution attributable death rate ...    Africa
# 1     Ambient air pollution attributable death rate ...    Africa
# 2     Ambient air pollution attributable death rate ...    Africa
# 3     Ambient air pollution attributable death rate ...    Africa
# 4     Ambient air pollution attributable death rate ...    Africa
# ...                                                 ...       ...
# 3263  Ambient air pollution attributable death rate ...    Africa
# 3265  Ambient air pollution attributable death rate ...    Africa
# 3269  Ambient air pollution attributable death rate ...    Africa
# 3274  Ambient air pollution attributable death rate ...    Africa
# 3280  Ambient air pollution attributable death rate ...    Africa
#
#                           Country  Year      Gender  \
# 0                          Malawi  2016      Female
# 1                           Niger  2016      Female
# 2     United Republic of Tanzania  2016      Female
# 3     United Republic of Tanzania  2016  Both sexes
# 4                          Malawi  2016  Both sexes
# ...                           ...   ...         ...
# 3263                Guinea-Bissau  2016      Female
# 3265                        Benin  2016        Male
# 3269                     Eswatini  2016      Female
# 3274                   Madagascar  2016      Female
# 3280     Central African Republic  2016  Both sexes
#
#                                 Cause  Average_death_Value
# 0     Trachea, bronchus, lung cancers             0.041000
# 1     Trachea, bronchus, lung cancers             0.047000
# 2     Trachea, bronchus, lung cancers             0.052000
# 3     Trachea, bronchus, lung cancers             0.056333
# 4     Trachea, bronchus, lung cancers             0.057333
# ...                               ...                  ...
# 3263          Ischaemic heart disease             9.786667
# 3265          Ischaemic heart disease             9.743333
# 3269     Lower respiratory infections            10.190000
# 3274     Lower respiratory infections            10.120000
# 3280                           Stroke             9.970000
#
# [954 rows x 7 columns]>

# %% [markdown]
# ## Cleaning the Particulate Matter Concentration dataset

# %%
#Assigning the dataframe a variable
PM_data=Data_frames('csv','Particulate Matter Concentration world wide...csv')
#Getting rid of null values
PM_data.dropna(axis=1,how='all',inplace=True)
PM_data.head()
# Dropping unnecessary columns
DPM_dataset= PM_data.drop(PM_data.columns[[0,2,3,5,6,8,10,11,13,17,18,19]], axis = 1)
DPM_dataset
# Renaming columns 
PM_Africa_df=DPM_dataset.rename(columns={'ParentLocation':'Continent','Location':'Country','Period':'Year','Dim1':'Status'})
PM_Africa_df
# Filtering out the African countries.
Our_New_df=PM_Africa_df[PM_Africa_df['Continent']=='Africa']
Our_New_df
# Constructing a new column with average
Our_New_df['Average_PM_Value']=Our_New_df[['FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']].mean(axis=1)
Our_New_df['Average_PM_Value']
#Dropping the Fact Numeric Value to remain with the mean
D_Our_New_df=Our_New_df.drop(Our_New_df.columns[[5,6,7]],axis=1)
D_Our_New_df
# Dropping duplicates
D_Our_New_df.drop_duplicates
D_Our_New_df.head()
# Out:
# <ipython-input-17-297777176680>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Our_New_df['Average_PM_Value']=Our_New_df[['FactValueNumeric','FactValueNumericLow','FactValueNumericHigh']].mean(axis=1)
#                                             Indicator Continent     Country  \
# 18  Concentrations of fine particulate matter (PM2.5)    Africa   Mauritius
# 43  Concentrations of fine particulate matter (PM2.5)    Africa   Mauritius
# 81  Concentrations of fine particulate matter (PM2.5)    Africa  Seychelles
# 82  Concentrations of fine particulate matter (PM2.5)    Africa  Seychelles
# 83  Concentrations of fine particulate matter (PM2.5)    Africa  Seychelles
#
#     Year Status  Average_PM_Value
# 18  2016  Total         11.426667
# 43  2016  Rural         12.173333
# 81  2016  Urban         15.043333
# 82  2016  Total         15.013333
# 83  2016  Rural         14.963333

# %%
#Confirming the cleaning operation on PM dataset
new_attributes(D_Our_New_df)
# Out:
# (987, 6)
#
#
# Indicator           0
# Continent           0
# Country             0
# Year                0
# Status              0
# Average_PM_Value    0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of                                               Indicator Continent     Country  \
# 18    Concentrations of fine particulate matter (PM2.5)    Africa   Mauritius
# 43    Concentrations of fine particulate matter (PM2.5)    Africa   Mauritius
# 81    Concentrations of fine particulate matter (PM2.5)    Africa  Seychelles
# 82    Concentrations of fine particulate matter (PM2.5)    Africa  Seychelles
# 83    Concentrations of fine particulate matter (PM2.5)    Africa  Seychelles
# ...                                                 ...       ...         ...
# 3977  Concentrations of fine particulate matter (PM2.5)    Africa  Mauritania
# 4004  Concentrations of fine particulate matter (PM2.5)    Africa       Niger
# 4019  Concentrations of fine particulate matter (PM2.5)    Africa       Niger
# 4020  Concentrations of fine particulate matter (PM2.5)    Africa       Niger
# 4025  Concentrations of fine particulate matter (PM2.5)    Africa   Mauritius
#
#       Year Status  Average_PM_Value
# 18    2016  Total         11.426667
# 43    2016  Rural         12.173333
# 81    2016  Urban         15.043333
# 82    2016  Total         15.013333
# 83    2016  Rural         14.963333
# ...    ...    ...               ...
# 3977  2010  Urban         76.216667
# 4004  2010  Urban         98.396667
# 4019  2010  Total        101.720000
# 4020  2010  Rural        103.263333
# 4025  2010  Urban         10.313333
#
# [987 rows x 6 columns]>

# %% [markdown]
# ## Cleaning the WHO emission database

# %%
# Assigning the Dataframe a variable to enable cleaning
WHO_df=Data_frames('csv','WHO_AirQuality_Database_2016_Africa.csv')
WHO_df
WHO_df.dropna(axis=1,how='all',inplace=True)
WHO_df.head()
# Dropping unnesessary columns
D_WHO_dataset=WHO_df.drop(WHO_df.columns[[0,5,6,8,9,10,11,14,15,16,17,18,19,20,22,23,24,25,26,27,28]],axis=1)
D_WHO_dataset
# Filtering out the African Region
WHO_New_df=D_WHO_dataset[D_WHO_dataset['Region']=='Africa (Sub-Saharan) (LMIC)']
WHO_New_df
# Renaming the columns
WHO_Africa_df=WHO_New_df.rename(columns={'wbinc16_text':'Income_status','Region':'Continent'})
WHO_Africa_df
# Organising Columns
Clean_WHO_Africa_df=WHO_Africa_df.replace('Africa (Sub-Saharan) (LMIC)','Africa')
Clean_WHO_Africa_df
# Out:
#         country            city    pm10  Year       pm25  population  \
# 2183  Mauritius      Port Louis   13.21  2016   6.467670    135496.0
# 2184  Mauritius  Vacoas-Phoenix   15.15  2016   7.417502    105253.0
# 2509    Senegal           Dakar  145.50  2016  25.000000   3520215.0
# 2960      Ghana           Accra  112.20  2016  55.000000   2277298.0
#
#             Income_status Continent
# 2183  Upper middle income    Africa
# 2184  Upper middle income    Africa
# 2509           Low income    Africa
# 2960  Lower middle income    Africa

# %%
#Confirming the cleaning operation
new_attributes(Clean_WHO_Africa_df)
# Out:
# (4, 8)
#
#
# country          0
# city             0
# pm10             0
# Year             0
# pm25             0
# population       0
# Income_status    0
# Continent        0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of         country            city    pm10  Year       pm25  population  \
# 2183  Mauritius      Port Louis   13.21  2016   6.467670    135496.0
# 2184  Mauritius  Vacoas-Phoenix   15.15  2016   7.417502    105253.0
# 2509    Senegal           Dakar  145.50  2016  25.000000   3520215.0
# 2960      Ghana           Accra  112.20  2016  55.000000   2277298.0
#
#             Income_status Continent
# 2183  Upper middle income    Africa
# 2184  Upper middle income    Africa
# 2509           Low income    Africa
# 2960  Lower middle income    Africa  >

# %% [markdown]
# ## Cleaning the CO2 dataset

# %%
#Assigning the CO2 dataframe a variable to enable cleaning
CO2_data=Data_frames('csv',"CO2 Emission in KT. in excel.csv")
CO2_data
#Dropping all unnecessary years from column index 3 upto 60
CO2_dropped_1= CO2_data.drop(CO2_data.iloc[:, 3:60].columns, axis = 1)
CO2_dropped_1
# Dropping all unnesessary columns from index column 4 up to the end
CO2_dropped_2= CO2_dropped_1.drop(CO2_dropped_1.iloc[:, 4:].columns, axis = 1)
#Renaming country name to country to enable merging
CO2_dropped_2.rename(columns={'Country Name':'Country'})
# Out:
#                         Country Country Code      Indicator Name        2016
# 0   Africa Eastern and Southern          AFE  CO2 emissions (kt)  592299.594
# 1    Africa Western and Central          AFW  CO2 emissions (kt)  195120.000
# 2                        Angola          AGO  CO2 emissions (kt)   35410.000
# 3                       Burundi          BDI  CO2 emissions (kt)     460.000
# 4                         Benin          BEN  CO2 emissions (kt)    7230.000
# ..                          ...          ...                 ...         ...
# 56                     Tanzania          TZA  CO2 emissions (kt)   10920.000
# 57                       Uganda          UGA  CO2 emissions (kt)    5670.000
# 58                 South Africa          ZAF  CO2 emissions (kt)  425180.000
# 59                       Zambia          ZMB  CO2 emissions (kt)    5590.000
# 60                     Zimbabwe          ZWE  CO2 emissions (kt)   10990.000
#
# [61 rows x 4 columns]

# %%
#Confiriming our cleaning operation on CO2 dataset
new_attributes(CO2_dropped_2)
# Out:
# (61, 4)
#
#
# Country Name      0
# Country Code      0
# Indicator Name    0
# 2016              0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of                    Country Name Country Code      Indicator Name        2016
# 0   Africa Eastern and Southern          AFE  CO2 emissions (kt)  592299.594
# 1    Africa Western and Central          AFW  CO2 emissions (kt)  195120.000
# 2                        Angola          AGO  CO2 emissions (kt)   35410.000
# 3                       Burundi          BDI  CO2 emissions (kt)     460.000
# 4                         Benin          BEN  CO2 emissions (kt)    7230.000
# ..                          ...          ...                 ...         ...
# 56                     Tanzania          TZA  CO2 emissions (kt)   10920.000
# 57                       Uganda          UGA  CO2 emissions (kt)    5670.000
# 58                 South Africa          ZAF  CO2 emissions (kt)  425180.000
# 59                       Zambia          ZMB  CO2 emissions (kt)    5590.000
# 60                     Zimbabwe          ZWE  CO2 emissions (kt)   10990.000
#
# [61 rows x 4 columns]>

# %% [markdown]
# ## Cleaning the Nitrogen Oxide Dataset

# %%
# Assigning the NO dataset a variable to enable cleaning
NO_dataset=Data_frames('xlsx','Nitogen Oxide Emissions edited.xlsx')
NO_dataset
# Dropping the the indicator code column and the column years 1960 to 2015 and the year afterwards
NO_dropped_1= NO_dataset.drop(NO_dataset.iloc[:, 3:60].columns, axis = 1)
NO_dropped_1
NO_dropped_2= NO_dropped_1.drop(NO_dropped_1.iloc[:, 4:9].columns, axis = 1)
NO_dropped_2.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1   Africa Western and Central          AFW
# 2                       Angola          AGO
# 3                      Burundi          BDI
# 4                        Benin          BEN
#
#                                       Indicator Name    2016
# 0  Nitrous oxide emissions (thousand metric tons ...  284380
# 1  Nitrous oxide emissions (thousand metric tons ...  228580
# 2  Nitrous oxide emissions (thousand metric tons ...   18070
# 3  Nitrous oxide emissions (thousand metric tons ...    2090
# 4  Nitrous oxide emissions (thousand metric tons ...    2670

# %%
#Confirming the cleaning operation on NO dataset
new_attributes(NO_dropped_2)
# Out:
# (59, 4)
#
#
# Country Name      0
# Country Code      0
# Indicator Name    0
# 2016              0
# dtype: int64
#
#
# False
#
#
# <bound method DataFrame.info of                                          Country Name Country Code  \
# 0                         Africa Eastern and Southern          AFE
# 1                          Africa Western and Central          AFW
# 2                                              Angola          AGO
# 3                                             Burundi          BDI
# 4                                               Benin          BEN
# 5                                        Burkina Faso          BFA
# 6                                            Botswana          BWA
# 7                            Central African Republic          CAF
# 8                                       Cote d'Ivoire          CIV
# 9                                            Cameroon          CMR
# 10                                   Congo, Dem. Rep.          COD
# 11                                        Congo, Rep.          COG
# 12                                            Comoros          COM
# 13                                         Cabo Verde          CPV
# 14                                           Djibouti          DJI
# 15                                            Algeria          DZA
# 16                                   Egypt, Arab Rep.          EGY
# 17                                            Eritrea          ERI
# 18                                           Ethiopia          ETH
# 19                                              Gabon          GAB
# 20                                              Ghana          GHA
# 21                                             Guinea          GIN
# 22                                        Gambia, The          GMB
# 23                                      Guinea-Bissau          GNB
# 24                                              Kenya          KEN
# 25                                            Liberia          LBR
# 26                                              Libya          LBY
# 27                                            Lesotho          LSO
# 28                                            Morocco          MAR
# 29                                         Madagascar          MDG
# 30                         Middle East & North Africa          MEA
# 31                                               Mali          MLI
# 32  Middle East & North Africa (excluding high inc...          MNA
# 33                                         Mozambique          MOZ
# 34                                         Mauritania          MRT
# 35                                          Mauritius          MUS
# 36                                             Malawi          MWI
# 37                                            Namibia          NAM
# 38                                              Niger          NER
# 39                                            Nigeria          NGA
# 40                                             Rwanda          RWA
# 41                                              Sudan          SDN
# 42                                            Senegal          SEN
# 43                                       Sierra Leone          SLE
# 44                                            Somalia          SOM
# 45                                        South Sudan          SSD
# 46                                 Sub-Saharan Africa          SSF
# 47                                           Eswatini          SWZ
# 48                                         Seychelles          SYC
# 49                                               Chad          TCD
# 50                                               Togo          TGO
# 51  Middle East & North Africa (IDA & IBRD countries)          TMN
# 52          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 53                                            Tunisia          TUN
# 54                                           Tanzania          TZA
# 55                                             Uganda          UGA
# 56                                       South Africa          ZAF
# 57                                             Zambia          ZMB
# 58                                           Zimbabwe          ZWE
#
#                                        Indicator Name    2016
# 0   Nitrous oxide emissions (thousand metric tons ...  284380
# 1   Nitrous oxide emissions (thousand metric tons ...  228580
# 2   Nitrous oxide emissions (thousand metric tons ...   18070
# 3   Nitrous oxide emissions (thousand metric tons ...    2090
# 4   Nitrous oxide emissions (thousand metric tons ...    2670
# 5   Nitrous oxide emissions (thousand metric tons ...    9830
# 6   Nitrous oxide emissions (thousand metric tons ...    2430
# 7   Nitrous oxide emissions (thousand metric tons ...   32140
# 8   Nitrous oxide emissions (thousand metric tons ...    3680
# 9   Nitrous oxide emissions (thousand metric tons ...   62700
# 10  Nitrous oxide emissions (thousand metric tons ...   16060
# 11  Nitrous oxide emissions (thousand metric tons ...    1980
# 12  Nitrous oxide emissions (thousand metric tons ...      50
# 13  Nitrous oxide emissions (thousand metric tons ...      80
# 14  Nitrous oxide emissions (thousand metric tons ...     270
# 15  Nitrous oxide emissions (thousand metric tons ...   11890
# 16  Nitrous oxide emissions (thousand metric tons ...   22130
# 17  Nitrous oxide emissions (thousand metric tons ...    2840
# 18  Nitrous oxide emissions (thousand metric tons ...   50870
# 19  Nitrous oxide emissions (thousand metric tons ...     440
# 20  Nitrous oxide emissions (thousand metric tons ...    5900
# 21  Nitrous oxide emissions (thousand metric tons ...    7210
# 22  Nitrous oxide emissions (thousand metric tons ...     390
# 23  Nitrous oxide emissions (thousand metric tons ...     770
# 24  Nitrous oxide emissions (thousand metric tons ...   18760
# 25  Nitrous oxide emissions (thousand metric tons ...    1360
# 26  Nitrous oxide emissions (thousand metric tons ...    1940
# 27  Nitrous oxide emissions (thousand metric tons ...     790
# 28  Nitrous oxide emissions (thousand metric tons ...    7940
# 29  Nitrous oxide emissions (thousand metric tons ...    9170
# 30  Nitrous oxide emissions (thousand metric tons ...  115790
# 31  Nitrous oxide emissions (thousand metric tons ...   13730
# 32  Nitrous oxide emissions (thousand metric tons ...   98310
# 33  Nitrous oxide emissions (thousand metric tons ...    9780
# 34  Nitrous oxide emissions (thousand metric tons ...    3370
# 35  Nitrous oxide emissions (thousand metric tons ...     240
# 36  Nitrous oxide emissions (thousand metric tons ...    3870
# 37  Nitrous oxide emissions (thousand metric tons ...    3260
# 38  Nitrous oxide emissions (thousand metric tons ...   11190
# 39  Nitrous oxide emissions (thousand metric tons ...   36210
# 40  Nitrous oxide emissions (thousand metric tons ...    1980
# 41  Nitrous oxide emissions (thousand metric tons ...   29670
# 42  Nitrous oxide emissions (thousand metric tons ...    7920
# 43  Nitrous oxide emissions (thousand metric tons ...    1750
# 44  Nitrous oxide emissions (thousand metric tons ...    6680
# 45  Nitrous oxide emissions (thousand metric tons ...   22800
# 46  Nitrous oxide emissions (thousand metric tons ...  512960
# 47  Nitrous oxide emissions (thousand metric tons ...     430
# 48  Nitrous oxide emissions (thousand metric tons ...       0
# 49  Nitrous oxide emissions (thousand metric tons ...   23360
# 50  Nitrous oxide emissions (thousand metric tons ...    1860
# 51  Nitrous oxide emissions (thousand metric tons ...   98310
# 52  Nitrous oxide emissions (thousand metric tons ...  512960
# 53  Nitrous oxide emissions (thousand metric tons ...    3340
# 54  Nitrous oxide emissions (thousand metric tons ...   30680
# 55  Nitrous oxide emissions (thousand metric tons ...   15070
# 56  Nitrous oxide emissions (thousand metric tons ...   17510
# 57  Nitrous oxide emissions (thousand metric tons ...   15170
# 58  Nitrous oxide emissions (thousand metric tons ...    6090  >

# %%
# Function to export the clean dataset
def clean_export(clean_df,name):
    clean_csv=clean_df.to_csv(name)
    return clean_csv

# %%
#Exporting the clean Mortality rate dataset
clean_export(D_New_df,'Clean Mortality rate dataset.csv')

# %%
# Exporting the clean Particulate matter dataset to csv
clean_export(D_Our_New_df,'Clean_PM.csv')

# %%
# Exporting the clean CO2 emission dataset
clean_export(CO2_dropped_2,'Clean CO2 dataset.csv')

# %%
# Exporting the clean NO dataset
clean_export(NO_dropped_2,'Clean NO dataset.csv')

# %% [markdown]
# ## DATA ANALYSIS

# %% [markdown]
# Function to Merge datasets

# %%
def merge(data1,data2,condition):
    merged_df=pd.merge(data1,data2,on=condition)
    return merged_df

# %%
# Merging our dataframe Deaths due to respiratory illneses,Particulate matter concentration on continent column
merge(D_New_df,D_Our_New_df,'Continent')
# Out:
#                                               Indicator_x Continent  \
# 0       Ambient air pollution attributable death rate ...    Africa
# 1       Ambient air pollution attributable death rate ...    Africa
# 2       Ambient air pollution attributable death rate ...    Africa
# 3       Ambient air pollution attributable death rate ...    Africa
# 4       Ambient air pollution attributable death rate ...    Africa
# ...                                                   ...       ...
# 941593  Ambient air pollution attributable death rate ...    Africa
# 941594  Ambient air pollution attributable death rate ...    Africa
# 941595  Ambient air pollution attributable death rate ...    Africa
# 941596  Ambient air pollution attributable death rate ...    Africa
# 941597  Ambient air pollution attributable death rate ...    Africa
#
#                        Country_x  Year_x      Gender  \
# 0                         Malawi    2016      Female
# 1                         Malawi    2016      Female
# 2                         Malawi    2016      Female
# 3                         Malawi    2016      Female
# 4                         Malawi    2016      Female
# ...                          ...     ...         ...
# 941593  Central African Republic    2016  Both sexes
# 941594  Central African Republic    2016  Both sexes
# 941595  Central African Republic    2016  Both sexes
# 941596  Central African Republic    2016  Both sexes
# 941597  Central African Republic    2016  Both sexes
#
#                                   Cause  Average_death_Value  \
# 0       Trachea, bronchus, lung cancers                0.041
# 1       Trachea, bronchus, lung cancers                0.041
# 2       Trachea, bronchus, lung cancers                0.041
# 3       Trachea, bronchus, lung cancers                0.041
# 4       Trachea, bronchus, lung cancers                0.041
# ...                                 ...                  ...
# 941593                           Stroke                9.970
# 941594                           Stroke                9.970
# 941595                           Stroke                9.970
# 941596                           Stroke                9.970
# 941597                           Stroke                9.970
#
#                                               Indicator_y   Country_y  Year_y  \
# 0       Concentrations of fine particulate matter (PM2.5)   Mauritius    2016
# 1       Concentrations of fine particulate matter (PM2.5)   Mauritius    2016
# 2       Concentrations of fine particulate matter (PM2.5)  Seychelles    2016
# 3       Concentrations of fine particulate matter (PM2.5)  Seychelles    2016
# 4       Concentrations of fine particulate matter (PM2.5)  Seychelles    2016
# ...                                                   ...         ...     ...
# 941593  Concentrations of fine particulate matter (PM2.5)  Mauritania    2010
# 941594  Concentrations of fine particulate matter (PM2.5)       Niger    2010
# 941595  Concentrations of fine particulate matter (PM2.5)       Niger    2010
# 941596  Concentrations of fine particulate matter (PM2.5)       Niger    2010
# 941597  Concentrations of fine particulate matter (PM2.5)   Mauritius    2010
#
#        Status  Average_PM_Value
# 0       Total         11.426667
# 1       Rural         12.173333
# 2       Urban         15.043333
# 3       Total         15.013333
# 4       Rural         14.963333
# ...       ...               ...
# 941593  Urban         76.216667
# 941594  Urban         98.396667
# 941595  Total        101.720000
# 941596  Rural        103.263333
# 941597  Urban         10.313333
#
# [941598 rows x 12 columns]

# %% [markdown]
# Function to merge the datasets  with no sililar columns on index

# %%
def merge1(data1,data2,condition1,condition2):
    merged1_df=pd.merge(data1,data2,left_index=condition1,right_index=condition2)
    return merged1_df

# %%
#Merging the Mortality dataframe with the CO2 emission database on index
merge1(D_New_df,CO2_dropped_2,True,True)

# %%
#Merging the Mortality dataframe with NO dataframe on index
merge1(D_New_df,NO_dropped_2,True,True)

# %% [markdown]
# # Objective one.
# ## To identify the countries with the highest Pollutant concentration

# %% [markdown]
# ## Which country had the highest Particulate Matter Concentration?

# %%
#The merged PM and death dataset
PM_death=merge(D_New_df,D_Our_New_df,'Continent')
# A function for sorting grouped columns
def high_pollutant(column1,column2,order):
    our_grouped=PM_death[column1].groupby(PM_death[column2]).max()
    sort_grouped=our_grouped.sort_values(ascending=order)
    return sort_grouped.head(10)
#Calling the function with sorted countries
high_pollutant('Average_PM_Value','Country_y',False)
# Out:
# Country_y
# Niger           120.943333
# Chad             95.753333
# Mauritania       93.703333
# Nigeria          91.803333
# Cabo Verde       84.576667
# Cameroon         82.493333
# Mali             80.876667
# Senegal          73.933333
# Gambia           70.953333
# Burkina Faso     69.073333
# Name: Average_PM_Value, dtype: float64

# %% [markdown]
# Niger had the highest PM concetration of 120.943333.
# It was followed closely by Chad,Mauritania,Nigeria,Carbo Verde,Cameroon as the top five countries with a high PM concentration in descending order

# %% [markdown]
# ## Which country had the highest CO2 concentration ?

# %%
#Asigning a variable to the Mortality and CO2 merged dataset
CO2_merged_df=merge1(D_New_df,CO2_dropped_2,True,True)
# Function to derive the country with the highest NO concentration
def high_CO2(column1,column2,order):
    CO2_death=CO2_merged_df[column1].groupby(CO2_merged_df[column2]).max()
    sort_CO2_death=CO2_death.sort_values(ascending=order)
    return sort_CO2_death.head(10)
#Calling the function with sorted countries with high CO2 emissions
high_CO2('2016','Country',False)
# Out:
# Country
# Angola                              785929.4530
# Burundi                             785929.4530
# Democratic Republic of the Congo    785390.5429
# Malawi                              592299.5940
# Nigeria                             425180.0000
# Gambia                              233960.0000
# Chad                                228009.3423
# Niger                               195120.0000
# Liberia                             143350.0000
# Congo                               108420.0000
# Name: 2016, dtype: float64

# %% [markdown]
# Angola and Burundi came in first with a CO2 concentration of 785929.4530.
# It was closeli followed by DRC,Malawi,Nigeria,Gambia,Chad,Niger and Liberia

# %% [markdown]
# ## Which country had the highest NO concentration?

# %%
#Asigning a variable to the Mortality and NO merged dataset
NO_merged_df=merge1(D_New_df,NO_dropped_2,True,True)
# Function to derive the country with the highest NO concentration
def high_NO(column1,column2,order):
    NO_death=NO_merged_df[column1].groupby(NO_merged_df[column2]).max()
    sort_NO_death=NO_death.sort_values(ascending=order)
    return sort_NO_death.head(10)
high_NO(2016,'Country',False)
# Out:
# Country
# Lesotho       512960
# Nigeria       512960
# Malawi        284380
# Niger         228580
# Chad          115790
# Mozambique     98310
# Guinea         62700
# Zambia         36210
# Liberia        32140
# Angola         30680
# Name: 2016, dtype: int64

# %% [markdown]
# Nigeria and Lesotho took a lead in this with an emission concentration of 512960. It was followed by Malawi,Niger,Chad,Mozambique,Guinea,Zambia,Liberia and Angola.

# %% [markdown]
# # Objective two

# %% [markdown]
# ## To identify the countries with the highest mortality rates due to respiratory conditions

# %%
# Calling the function with Mortality rates. 
# It should be noted that i am using the PM-Mortality merged dataset.
# The country_x however refers to the country column in the Mortality rate dataset(not the particulate matter dataset) thus doenot affect our findings.
high_pollutant('Average_death_Value','Country_x',False)
# Out:
# Country_x
# Chad                        87.823333
# Egypt                       77.533333
# Nigeria                     76.036667
# Niger                       71.830000
# Cameroon                    66.610000
# Tunisia                     66.333333
# Central African Republic    62.136667
# Côte d’Ivoire               59.640000
# Somalia                     59.540000
# Sudan                       57.393333
# Name: Average_death_Value, dtype: float64

# %% [markdown]
# Chad has the highest mortality rate. Followed closely by Egypt,Nigeria,Niger and Cameroon. It is to be noted with concern that the 4 out of top five countries with high mortality rates are among the "hall of fame" of countries with the highest pollutant levels all together.

# %% [markdown]
# # Objective three

# %% [markdown]
# ## To identify the gender with the highest mortality rate

# %% [markdown]
# Which gender is most affected by the death due to respiratory diseases?

# %%
# Calling the Merged PM_Mortality rate dataset. 
# It should be noted that both Gender and Average Death value belong to the mortality rate dataset 
# Thus using the merged df does not affect our results.
high_pollutant('Average_death_Value','Gender',False)
# Out:
# Gender
# Male          87.823333
# Both sexes    83.560000
# Female        79.300000
# Name: Average_death_Value, dtype: float64

# %% [markdown]
# The Male gender was highly affected as compared to the Female gender. Both sexes refers to the values which were unclassified either of the genders.

# %% [markdown]
# # Objective four

# %% [markdown]
# ## What was the cause of death across the continent?

# %%
# Calling the Merged PM_Mortality rate dataset. 
# It should be noted that both Cause of death and Average Death value belong to the mortality rate dataset 
# Thus using the merged df does not affect our results.
high_pollutant('Average_death_Value','Cause',False)
# Out:
# Cause
# Total                                    87.823333
# Lower respiratory infections             64.380000
# Ischaemic heart disease                  44.556667
# Stroke                                   13.090000
# Chronic obstructive pulmonary disease     9.226667
# Trachea, bronchus, lung cancers           5.800000
# Name: Average_death_Value, dtype: float64

# %% [markdown]
# # Static Visualization

# %% [markdown]
# Importing the necessary libraries for plotting graphs.

# %%
import seaborn as sns
# import plotly.express as px
import matplotlib.pyplot as plt

# %%
# Defining a function for drawing bargraphs
def visualization(col_x,col_y,df,title):
    graph=plt.figure(figsize=(16,12))
    graph=sns.barplot(x=col_x,y=col_y,data=df).set_title(title)
    graph=plt.show()
    return graph

# %% [markdown]
# ## A graph of countries in Africa against the Average PM concentration

# %%
#Assigning a variable  to the merged Mortality-Particulate matter dataset.
Country_PM=merge(D_New_df,D_Our_New_df,'Continent')
#A graph of countries in Africa against the Average PM concentration.
visualization('Average_PM_Value','Country_y',Country_PM,"Countries in Africa against Average PM concentration")

# %% [markdown]
# ## A graph of Countries in Africa against the CO2 concentration

# %%
#Asigning the merged Mortality rate C02 concentration dataset.
Country_CO2=merge1(D_New_df,CO2_dropped_2,True,True)
# A graph of Countries in Africa against the CO2 concentration.
visualization('2016','Country',Country_CO2,"Countries in Africa against CO2 concentration")

# %% [markdown]
# ## A graph of countries in Africa against the Nitrogen Oxide Concentration.

# %%
#Assigning a variable to the merged NO-Deathrate dataset.
Country_NO=merge1(D_New_df,NO_dropped_2,True,True)
# A graph of Countries in Africa against the NO concentration.
visualization(2016,'Country',Country_NO,"Countries in Africa against their Nitrogen Oxide concentration")

# %% [markdown]
# # A graph of Gender against Mortality rate

# %%
#Picking Gender and Death rate from the Merged PM -deathrate dataset.
visualization('Gender','Average_death_Value',Country_PM,"A graph of gender against Mortality rate")

# %% [markdown]
# ## A graph of the Cause of death accross Africa with its respective mortality rates.

# %%
# Picking Cause of death and Death rate from the Merged PM -deathrate dataset.
visualization('Cause','Average_death_Value',Country_PM,"A graph of cause of death against Mortality rate")

# %% [markdown]
# # Interactive Visualization
